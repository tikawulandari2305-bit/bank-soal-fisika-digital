# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
data  = pd.read_excel("/bank_soal.xlsx")
data
# Out:
#      id                                      soal opsi_a   opsi_b  opsi_c  \
# 0  Q001  Berapakah kuat arus jika V=10V dan R=5Ω?   0,5A       2A      5A
# 1  Q002                Satuan kuat arus adalah...   Volt  Coulomb  Ampere
#
#   opsi_d jawaban_benar level_bloom         materi
# 0    50A            2A          C2      Hukum Ohm
# 1    Ohm        Ampere          C1  Listrik Dasar

# %%
import pandas as pd
data  = pd.read_excel("/Book2.xlsx")
data
# Out:
#    nama Q001    Q002
# 0  Andi   2A  Ampere
# 1  Budi   5A    Volt
# 2  Cici   2A  Ampere

# %%
import pandas as pd

# 1️⃣ Baca dua file
bank = pd.read_excel("/bank_soal.xlsx")
jawaban = pd.read_excel("/Book2.xlsx")

# 2️⃣ Siapkan kunci jawaban
kunci = dict(zip(bank["id"], bank["jawaban_benar"]))
soal_list = list(kunci.keys())

# 3️⃣ Analisis setiap siswa
hasil = []
for idx, row in jawaban.iterrows():
    nama = row["nama"]
    skor_total = 0
    total_soal = len(soal_list)

    # Catatan untuk per materi dan per level
    benar_materi = {}
    benar_level = {}

    for q in soal_list:
        benar = str(row[q]).strip().lower() == str(kunci[q]).strip().lower()
        if benar:
            skor_total += 1

        # Ambil info dari bank soal
        materi = bank.loc[bank["id"] == q, "materi"].values[0]
        level = bank.loc[bank["id"] == q, "level_bloom"].values[0]

        # Hitung benar per materi
        benar_materi[materi] = benar_materi.get(materi, 0) + (1 if benar else 0)
        benar_level[level] = benar_level.get(level, 0) + (1 if benar else 0)

    # 4️⃣ Buat nilai total
    nilai = (skor_total / total_soal) * 100

    # 5️⃣ Buat kesimpulan otomatis
    kesimpulan = []

    # Evaluasi per materi
    for materi in bank["materi"].unique():
        jumlah_soal = len(bank[bank["materi"] == materi])
        benar = benar_materi.get(materi, 0)
        if benar < jumlah_soal / 2:
            kesimpulan.append(f"Lemah di materi {materi}")
        else:
            kesimpulan.append(f"Sudah menguasai materi {materi}")

    # Evaluasi per level Bloom
    for level in bank["level_bloom"].unique():
        jumlah_level = len(bank[bank["level_bloom"] == level])
        benar = benar_level.get(level, 0)
        if benar < jumlah_level / 2:
            kesimpulan.append(f"Perlu meningkatkan kemampuan {level} ({'mengingat' if level=='C1' else 'memahami'})")
        else:
            kesimpulan.append(f"Sudah baik pada level {level}")

    hasil.append({
        "nama": nama,
        "skor_benar": skor_total,
        "total_soal": total_soal,
        "nilai": nilai,
        "kesimpulan": "; ".join(kesimpulan)
    })

# 6️⃣ Simpan hasil ke Excel
hasil_df = pd.DataFrame(hasil)
hasil_df.to_excel("hasil_nilai_dengan_kesimpulan.xlsx", index=False)

print(hasil_df)
# Out:
#    nama  skor_benar  total_soal  nilai  \
# 0  Andi           2           2  100.0
# 1  Budi           0           2    0.0
# 2  Cici           2           2  100.0
#
#                                           kesimpulan
# 0  Sudah menguasai materi Hukum Ohm; Sudah mengua...
# 1  Lemah di materi Hukum Ohm; Lemah di materi Lis...
# 2  Sudah menguasai materi Hukum Ohm; Sudah mengua...
